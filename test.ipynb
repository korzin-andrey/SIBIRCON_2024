# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
people = pd.read_csv('data/chelyabinsk/people.txt', sep='\t', index_col=0)
people.loc[[1,2,3], ['age', 'sex']] = [[-5, 'G'], [-5, 'G'], [-5, 'G']] 
people
# Out:
#            sp_id  sp_hh_id  age sex work_id
# 0         599955         1    8   F      48
# 1         293648         1   -5   G       1
# 2         556704         1   -5   G       X
# 3         293647         2   -5   G       1
# 4        1094293         2   69   F       X
# ...          ...       ...  ...  ..     ...
# 1189520   462547    471999   61   M       X
# 1189521    74968    472001    9   M      71
# 1189522   551174    472001    0   F       X
# 1189523   888930    472002   44   F   74931
# 1189524   963144    472002   53   F   74931
#
# [1189525 rows x 5 columns]

# %%
import csv

number_of_launches = 8
data_launches = [[] for _ in range(number_of_launches)]
for launch_id in range(number_of_launches):
    incidence= pd.read_csv(r'results/chelyabinsk/incidence_{}.csv'.format(launch_id))['data'].to_list()
    data_launches[launch_id] = incidence
    plt.plot(incidence, color='royalblue')    
data_launches = np.array(data_launches)
mean_inc = np.mean(data_launches, axis=0)
plt.plot(mean_inc, color='red', lw=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 9
#       7     data_launches[launch_id] = incidence
#       8     plt.plot(incidence, color='royalblue')
# ----> 9 data_launches = np.array(data_launches)
#      10 mean_inc = np.mean(data_launches, axis=0)
#      11 plt.plot(mean_inc, color='red', lw=3)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (8,) + inhomogeneous part.

# %% [markdown]
# Epid data analytics

# %%
epid_data = pd.read_csv('./epid_data/SPb.COVID-19.united.csv')
wave = epid_data['CONFIRMED.sk'][670:800]
wave.to_csv('./epid_data/')
plt.plot(wave, '--o')
# plt.xlabel('Day')
# plt.ylabel('Incidence')
# plt.title('2 wave COVID-19')
# plt.plot(epid_data['CONFIRMED.spb'])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 epid_data = pd.read_csv('./epid_data/SPb.COVID-19.united.csv')
#       2 wave = epid_data['CONFIRMED.sk'][670:800]
# ----> 3 wave.to_csv('./epid_data/')
#       4 plt.plot(wave, '--o')
#       5 # plt.xlabel('Day')
#       6 # plt.ylabel('Incidence')
#       7 # plt.title('2 wave COVID-19')
#       8 # plt.plot(epid_data['CONFIRMED.spb'])
#
# File c:\Users\user\COVID_ABM\.env\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
# ...

# %%
people = pd.read_csv('./data/spb/people.txt', sep='\t', index_col=0)
households = pd.read_csv('./data/spb/households.txt', sep='\t') 
people_chosen_hh = people.iloc[1:5].sp_hh_id.to_list()
households_chosen = households.loc[households['sp_id'].isin(people_chosen_hh), :]

# %%
output = pd.DataFrame(columns=['latitude', 'longitude'])
# Out:
# 0    59.646232
# 1    59.646232
# 2    59.646232
# 3    59.646232
# 4    59.646232
# 5    59.646232
# 6    59.646232
# Name: latitude, dtype: float64
